# %% [markdown]
# # Data EDA

# %%
# %matplotlib inline
from __future__ import print_function
from __future__ import division

import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
import statsmodels.api as sm

# just for the sake of this blog post!
from warnings import filterwarnings
filterwarnings('ignore')

# %%
# load the provided data
train_features = pd.read_csv('data/final_dengue_features_train.csv')

train_labels = pd.read_csv('data/final_dengue_labels_train.csv')

# %%
# 圣胡安数据分离
sj_train_features = train_features[train_features['city'] == 1]
sj_train_labels = train_labels[train_labels['city'] ==1]

# 伊基托斯数据分离
iq_train_features = train_features[train_features['city'] == 0]
iq_train_labels = train_labels[train_labels['city'] == 0]

# %%
print('San Juan')
print('features: ', sj_train_features.shape)
print('labels  : ', sj_train_labels.shape)

print('\nIquitos')
print('features: ', iq_train_features.shape)
print('labels  : ', iq_train_labels.shape)
# Out:
# San Juan
# features:  (936, 24)
# labels  :  (936, 4)
#
# Iquitos
# features:  (520, 24)
# labels  :  (520, 4)

# %%
sj_train_features.head()
# Out:
#    year  weekofyear  week_start_date   ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# 0  1990          18           726587  0.122600  0.103725  0.198483  0.177617
# 1  1990          19           726594  0.169900  0.142175  0.162357  0.155486
# 2  1990          20           726601  0.032250  0.172967  0.157200  0.170843
# 3  1990          21           726608  0.128633  0.245067  0.227557  0.235886
# 4  1990          22           726615  0.196200  0.262200  0.251200  0.247340
#
#    precipitation_amt_mm  reanalysis_air_temp_k  reanalysis_avg_temp_k  ...  \
# 0                 12.42             297.572857             297.742857  ...
# 1                 22.82             298.211429             298.442857  ...
# 2                 34.54             298.781429             298.878571  ...
# 3                 15.36             298.987143             299.228571  ...
# 4                  7.52             299.518571             299.664286  ...
#
#    reanalysis_relative_humidity_percent  reanalysis_sat_precip_amt_mm  \
# 0                             73.365714                         12.42
# 1                             77.368571                         22.82
# 2                             82.052857                         34.54
# 3                             80.337143                         15.36
# 4                             80.460000                          7.52
#
#    reanalysis_specific_humidity_g_per_kg  reanalysis_tdtr_k  \
# 0                              14.012857           2.628571
# 1                              15.372857           2.371429
# 2                              16.848571           2.300000
# 3                              16.672857           2.428571
# 4                              17.210000           3.014286
#
#    station_avg_temp_c  station_diur_temp_rng_c  station_max_temp_c  \
# 0           25.442857                 6.900000                29.4
# 1           26.714286                 6.371429                31.7
# 2           26.714286                 6.485714                32.2
# 3           27.471429                 6.771429                33.3
# 4           28.942857                 9.371429                35.0
#
#    station_min_temp_c  station_precip_mm  city
# 0                20.0               16.0     1
# 1                22.2                8.6     1
# 2                22.8               41.4     1
# 3                23.3                4.0     1
# 4                23.9                5.8     1
#
# [5 rows x 24 columns]

# %%
# Remove `week_start_date` string.
sj_train_features.drop(['week_start_date','city'], axis=1, inplace=True)
iq_train_features.drop(['week_start_date','city'], axis=1, inplace=True)
sj_train_labels.drop('city', axis=1, inplace=True)
iq_train_labels.drop('city', axis=1, inplace=True)

# %%
# Merge the datasets on common columns
sj_df = pd.merge(sj_train_features, sj_train_labels, how="inner")
iq_df = pd.merge(iq_train_features, iq_train_labels, how="inner")
# 前移一周
sj_df['total_cases'] = sj_df['total_cases'].shift(-1)
iq_df['total_cases'] = iq_df['total_cases'].shift(-1)
# 刪除最後一個
sj_df = sj_df.iloc[:-1].reset_index(drop=True)
sj_df['total_cases'] = sj_df['total_cases'].astype(int)
iq_df = iq_df.iloc[:-1].reset_index(drop=True)
iq_df['total_cases'] = iq_df['total_cases'].astype(int)
#split
train_df_sj = sj_df.head(600)
test_df_sj = sj_df.tail(sj_df.shape[0] - 600) #936-800 = 136
train_df_iq = iq_df.head(400)
test_df_iq = iq_df.tail(iq_df.shape[0] - 400) #936-800 = 136
# 確保數據按照時間順序排列
train_df_sj = train_df_sj.sort_values(by=["year", "weekofyear"])
test_df_sj = test_df_sj.sort_values(by=["year", "weekofyear"])
train_df_iq = train_df_iq.sort_values(by=["year", "weekofyear"])
test_df_iq = test_df_iq.sort_values(by=["year", "weekofyear"])

# %%
# 構建 CNN + LSTM 模型(sj)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Conv1D, MaxPooling1D


# 選擇要預測的目標變數
target = ['total_cases']
X_train = train_df_sj.drop(columns=target).values
y_train = train_df_sj[target].values
X_test = test_df_sj.drop(columns=target).values
y_test = test_df_sj[target].values

# 標準化數據
scaler = MinMaxScaler(feature_range=(0, 1))
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 轉換為 3D 時序格式 (samples, time steps, features)
def create_sequences(X, y, time_steps=10):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        Xs.append(X[i:i+time_steps])
        ys.append(y[i+time_steps])
    return np.array(Xs), np.array(ys)

time_steps = 10  # 設定時序窗口大小
X_train_seq, y_train_seq = create_sequences(X_train_scaled, y_train, time_steps)
X_test_seq, y_test_seq = create_sequences(X_test_scaled, y_test, time_steps)
model_sj = Sequential([
    Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(time_steps, X_train.shape[1])),
    MaxPooling1D(pool_size=2),
    LSTM(50, return_sequences=True),
    Dropout(0.2),
    LSTM(50, return_sequences=False),
    Dropout(0.2),
    Dense(25, activation='relu'),
    Dense(1)  # 預測值輸出層
])

model_sj.compile(optimizer='adam', loss='mse')

# 訓練模型
history = model_sj.fit(X_train_seq, y_train_seq, epochs=50, batch_size=16, validation_data=(X_test_seq, y_test_seq))

# 預測
y_pred = model_sj.predict(X_test_seq)

# 視覺化損失曲線
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("CNN + LSTM Training Loss Curve")
plt.legend()
plt.grid(True)
plt.show()

# 視覺化預測結果
plt.figure(figsize=(12, 6))
plt.plot(y_test_seq, label="Actual Cases", color='blue')
plt.plot(y_pred, label="Predicted Cases", color='red', linestyle='dashed')
plt.xlabel("Time")
plt.ylabel("Total Cases")
plt.title("CNN + LSTM Prediction Results")
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 6533.4492 - val_loss: 756.0026
# Epoch 2/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3647.3755 - val_loss: 640.6531
# Epoch 3/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4473.7246 - val_loss: 763.8451
# Epoch 4/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5657.0664 - val_loss: 969.1014
# Epoch 5/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4108.3955 - val_loss: 1137.1362
# Epoch 6/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4936.0112 - val_loss: 1140.7758
# Epoch 7/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3740.4517 - val_loss: 1134.1353
# Epoch 8/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4341.2646 - val_loss: 1170.2717
# Epoch 9/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3355.0818 - val_loss: 1136.5750
# Epoch 10/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3347.6514 - val_loss: 670.4891
# Epoch 11/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2629.9138 - val_loss: 795.7317
# Epoch 12/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3155.3000 - val_loss: 651.0617
# Epoch 13/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2581.3503 - val_loss: 691.6418
# Epoch 14/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2743.3945 - val_loss: 552.5349
# Epoch 15/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1873.4296 - val_loss: 1725.4819
# Epoch 16/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3457.9060 - val_loss: 565.1804
# Epoch 17/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2798.0076 - val_loss: 598.0881
# Epoch 18/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3325.0244 - val_loss: 590.4240
# Epoch 19/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2423.6143 - val_loss: 875.5314
# Epoch 20/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2660.1101 - val_loss: 640.0881
# Epoch 21/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2672.3425 - val_loss: 1307.1606
# Epoch 22/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2669.2451 - val_loss: 1025.8031
# Epoch 23/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2597.0051 - val_loss: 1097.8459
# Epoch 24/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2619.9946 - val_loss: 1705.4921
# Epoch 25/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2196.6042 - val_loss: 950.0842
# Epoch 26/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2338.4478 - val_loss: 2020.6791
# Epoch 27/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2431.0286 - val_loss: 1841.5371
# Epoch 28/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2288.1116 - val_loss: 1761.1187
# Epoch 29/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2489.0923 - val_loss: 2508.7209
# Epoch 30/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2784.4856 - val_loss: 1979.9055
# Epoch 31/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2329.8691 - val_loss: 1616.2346
# Epoch 32/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2298.3899 - val_loss: 1328.1796
# Epoch 33/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1712.6171 - val_loss: 1684.2235
# Epoch 34/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1671.7974 - val_loss: 2405.6638
# Epoch 35/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1747.6421 - val_loss: 647.9301
# Epoch 36/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1527.9757 - val_loss: 1555.9224
# Epoch 37/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2103.0715 - val_loss: 1799.1444
# Epoch 38/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1787.9435 - val_loss: 2263.2588
# Epoch 39/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1799.0416 - val_loss: 1531.3076
# Epoch 40/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1426.3444 - val_loss: 1263.3328
# Epoch 41/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1597.5397 - val_loss: 1205.9458
# Epoch 42/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1149.7953 - val_loss: 619.4779
# Epoch 43/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1516.1715 - val_loss: 787.1609
# Epoch 44/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1573.9152 - val_loss: 1705.3152
# Epoch 45/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1515.2804 - val_loss: 689.4240
# Epoch 46/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1377.0338 - val_loss: 1543.1931
# Epoch 47/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2069.3191 - val_loss: 3385.2485
# Epoch 48/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1618.8270 - val_loss: 1319.5073
# Epoch 49/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1116.3292 - val_loss: 1217.2712
# Epoch 50/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 894.6209 - val_loss: 1774.1052
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
# 構建 CNN + LSTM 模型(iq)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Conv1D, MaxPooling1D


# 選擇要預測的目標變數
target = ['total_cases']
X_train = train_df_iq.drop(columns=target).values
y_train = train_df_iq[target].values
X_test = test_df_iq.drop(columns=target).values
y_test = test_df_iq[target].values

# 標準化數據
scaler = MinMaxScaler(feature_range=(0, 1))
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 轉換為 3D 時序格式 (samples, time steps, features)
def create_sequences(X, y, time_steps=10):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        Xs.append(X[i:i+time_steps])
        ys.append(y[i+time_steps])
    return np.array(Xs), np.array(ys)

time_steps = 10  # 設定時序窗口大小
X_train_seq, y_train_seq = create_sequences(X_train_scaled, y_train, time_steps)
X_test_seq, y_test_seq = create_sequences(X_test_scaled, y_test, time_steps)
model_iq = Sequential([
    Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(time_steps, X_train.shape[1])),
    MaxPooling1D(pool_size=2),
    LSTM(50, return_sequences=True),
    Dropout(0.2),
    LSTM(50, return_sequences=False),
    Dropout(0.2),
    Dense(25, activation='relu'),
    Dense(1)  # 預測值輸出層
])

model_iq.compile(optimizer='adam', loss='mse')

# 訓練模型
history = model_iq.fit(X_train_seq, y_train_seq, epochs=50, batch_size=16, validation_data=(X_test_seq, y_test_seq))

# 預測
y_pred = model_iq.predict(X_test_seq)

# 視覺化損失曲線
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("CNN + LSTM Training Loss Curve")
plt.legend()
plt.grid(True)
plt.show()

# 視覺化預測結果
plt.figure(figsize=(12, 6))
plt.plot(y_test_seq, label="Actual Cases", color='blue')
plt.plot(y_pred, label="Predicted Cases", color='red', linestyle='dashed')
plt.xlabel("Time")
plt.ylabel("Total Cases")
plt.title("CNN + LSTM Prediction Results")
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 131.3121 - val_loss: 142.9683
# Epoch 2/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 102.3477 - val_loss: 129.0340
# Epoch 3/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 89.1279 - val_loss: 130.5124
# Epoch 4/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 162.6436 - val_loss: 130.0503
# Epoch 5/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 173.2463 - val_loss: 131.4382
# Epoch 6/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 125.8431 - val_loss: 129.1268
# Epoch 7/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 106.8297 - val_loss: 133.6673
# Epoch 8/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 160.8280 - val_loss: 138.7034
# Epoch 9/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 102.7314 - val_loss: 128.5306
# Epoch 10/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 156.0335 - val_loss: 126.9024
# Epoch 11/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 81.2015 - val_loss: 126.7637
# Epoch 12/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 86.7953 - val_loss: 134.0986
# Epoch 13/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 138.9127 - val_loss: 132.3115
# Epoch 14/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 73.2727 - val_loss: 143.8696
# Epoch 15/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 110.0660 - val_loss: 129.1064
# Epoch 16/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 82.6392 - val_loss: 126.6633
# Epoch 17/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 118.6740 - val_loss: 151.0517
# Epoch 18/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 69.1891 - val_loss: 127.7184
# Epoch 19/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 63.1901 - val_loss: 133.3428
# Epoch 20/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 126.4010 - val_loss: 128.3928
# Epoch 21/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 93.1086 - val_loss: 131.8911
# Epoch 22/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 68.2069 - val_loss: 172.8097
# Epoch 23/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 72.0762 - val_loss: 131.1104
# Epoch 24/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 105.9756 - val_loss: 137.5678
# Epoch 25/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 84.3619 - val_loss: 135.3919
# Epoch 26/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 121.0528 - val_loss: 175.1968
# Epoch 27/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 114.4880 - val_loss: 137.7149
# Epoch 28/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 144.4488 - val_loss: 158.0139
# Epoch 29/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 88.0321 - val_loss: 165.8634
# Epoch 30/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 99.4711 - val_loss: 140.8421
# Epoch 31/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 70.7834 - val_loss: 141.6567
# Epoch 32/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 90.3877 - val_loss: 209.7059
# Epoch 33/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 96.0705 - val_loss: 167.1712
# Epoch 34/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 59.4973 - val_loss: 203.8428
# Epoch 35/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 108.0010 - val_loss: 250.1439
# Epoch 36/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 41.2600 - val_loss: 196.5086
# Epoch 37/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 90.7933 - val_loss: 150.0060
# Epoch 38/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 51.4072 - val_loss: 154.3534
# Epoch 39/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 69.4112 - val_loss: 141.8454
# Epoch 40/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 94.3486 - val_loss: 139.8760
# Epoch 41/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 63.5180 - val_loss: 136.7293
# Epoch 42/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 58.2895 - val_loss: 126.4157
# Epoch 43/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 65.3795 - val_loss: 131.6358
# Epoch 44/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 86.8796 - val_loss: 131.3786
# Epoch 45/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 57.0648 - val_loss: 254.4623
# Epoch 46/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 54.9046 - val_loss: 257.0976
# Epoch 47/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 62.3417 - val_loss: 144.7057
# Epoch 48/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 45.3566 - val_loss: 330.7906
# Epoch 49/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 55.7120 - val_loss: 141.2398
# Epoch 50/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 64.8540 - val_loss: 129.8758
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Conv1D, MaxPooling1D

# 選擇要預測的目標變數
target = ['total_cases']
X_train = train_df_iq.drop(columns=target).values
y_train = train_df_iq[target].values
X_test = test_df_iq.drop(columns=target).values
y_test = test_df_iq[target].values

# 標準化數據
scaler = MinMaxScaler(feature_range=(0, 1))
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 構建 CNN + LSTM 模型
model_iq = Sequential([
    Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_train_scaled.shape[1], 1)),
    MaxPooling1D(pool_size=2),
    LSTM(50, return_sequences=True),
    Dropout(0.2),
    LSTM(50, return_sequences=False),
    Dropout(0.2),
    Dense(25, activation='relu'),
    Dense(1)  # 預測值輸出層
])

model_iq.compile(optimizer='adam', loss='mse')

# 調整輸入形狀以適應 Conv1D 和 LSTM 要求
X_train_scaled = np.expand_dims(X_train_scaled, axis=2)
X_test_scaled = np.expand_dims(X_test_scaled, axis=2)

# 訓練模型
history = model_iq.fit(X_train_scaled, y_train, epochs=50, batch_size=16, validation_data=(X_test_scaled, y_test))

# 預測
y_pred = model_iq.predict(X_test_scaled)

# 視覺化損失曲線
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("CNN + LSTM Training Loss Curve")
plt.legend()
plt.grid(True)
plt.show()

# 視覺化預測結果
plt.figure(figsize=(12, 6))
plt.plot(y_test, label="Actual Cases", color='blue')
plt.plot(y_pred, label="Predicted Cases", color='red', linestyle='dashed')
plt.xlabel("Time")
plt.ylabel("Total Cases")
plt.title("CNN + LSTM Prediction Results")
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 145.7378 - val_loss: 150.6878
# Epoch 2/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 192.5566 - val_loss: 122.9269
# Epoch 3/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 88.1352 - val_loss: 123.2510
# Epoch 4/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 100.6725 - val_loss: 121.8679
# Epoch 5/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 108.9607 - val_loss: 122.0952
# Epoch 6/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 129.4883 - val_loss: 122.9273
# Epoch 7/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 112.9813 - val_loss: 122.3483
# Epoch 8/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 91.7128 - val_loss: 122.4959
# Epoch 9/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 83.2883 - val_loss: 122.4430
# Epoch 10/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 133.0841 - val_loss: 122.6380
# Epoch 11/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 82.4261 - val_loss: 122.1018
# Epoch 12/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 97.0477 - val_loss: 121.7822
# Epoch 13/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 135.2829 - val_loss: 122.6116
# Epoch 14/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 156.1464 - val_loss: 122.6357
# Epoch 15/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 124.8503 - val_loss: 122.6804
# Epoch 16/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 191.1584 - val_loss: 121.7739
# Epoch 17/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 101.1733 - val_loss: 123.1983
# Epoch 18/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 85.0873 - val_loss: 122.6251
# Epoch 19/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 107.9361 - val_loss: 122.2315
# Epoch 20/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 107.3887 - val_loss: 122.6082
# Epoch 21/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 115.9235 - val_loss: 122.3263
# Epoch 22/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 72.8104 - val_loss: 121.4004
# Epoch 23/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 116.7842 - val_loss: 123.4431
# Epoch 24/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 98.4343 - val_loss: 121.4545
# Epoch 25/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 94.4042 - val_loss: 120.7174
# Epoch 26/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 80.8363 - val_loss: 122.8076
# Epoch 27/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 172.7863 - val_loss: 122.6209
# Epoch 28/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 161.6111 - val_loss: 123.0374
# Epoch 29/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 101.0950 - val_loss: 120.9631
# Epoch 30/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 126.6045 - val_loss: 122.3015
# Epoch 31/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 83.8550 - val_loss: 121.0419
# Epoch 32/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 117.2032 - val_loss: 122.4550
# Epoch 33/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 126.3662 - val_loss: 122.1813
# Epoch 34/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 150.7014 - val_loss: 122.2366
# Epoch 35/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 130.6420 - val_loss: 123.8456
# Epoch 36/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 84.1170 - val_loss: 126.7911
# Epoch 37/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 172.7258 - val_loss: 129.5593
# Epoch 38/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 67.1666 - val_loss: 131.8549
# Epoch 39/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 130.8592 - val_loss: 131.9084
# Epoch 40/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 79.7956 - val_loss: 138.4663
# Epoch 41/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 81.0933 - val_loss: 146.5215
# Epoch 42/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 87.4536 - val_loss: 150.8056
# Epoch 43/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 90.1164 - val_loss: 128.4889
# Epoch 44/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 102.7686 - val_loss: 150.9975
# Epoch 45/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 118.3709 - val_loss: 148.7752
# Epoch 46/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 61.9883 - val_loss: 153.0316
# Epoch 47/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 99.6394 - val_loss: 148.7680
# Epoch 48/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 106.1623 - val_loss: 173.4899
# Epoch 49/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 81.1581 - val_loss: 177.2324
# Epoch 50/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 93.5053 - val_loss: 147.2702
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.preprocessing.sequence import pad_sequences

test_data =pd.read_csv("data/dengue_features_test.csv")
# 删除不必要的列（如果有）
test_data = test_data.drop(columns=['week_start_date'], errors='ignore')
# 圣胡安数据分离
test_data_sj = test_data[test_data['city'] == 'sj']
test_data_sj = test_data_sj.drop(columns=['city'], errors='ignore')
# 伊基托斯数据分离
test_data_iq = test_data[test_data['city'] == 'iq']
test_data_iq = test_data_iq.drop(columns=['city'], errors='ignore')
# # 归一化测试数据（使用训练时的 scaler）
X_test_scaled_sj = scaler.transform(test_data_sj.values)
X_test_scaled_iq = scaler.transform(test_data_iq.values)
print(len(X_test_scaled_sj)+len(X_test_scaled_iq))
# # # 创建时间序列数据
# X_test_seq_sj, _ = create_sequences(X_test_scaled_sj, np.zeros(len(X_test_scaled_sj)), time_steps=10)  # 目标值设为0
# X_test_seq_iq, _ = create_sequences(X_test_scaled_iq, np.zeros(len(X_test_scaled_iq)), time_steps=10)  # 目标值设为0
# Out:
# 416

# %%
# 獲取測試數據的長度
# num_test_sj = len(X_test_scaled_sj)
# num_test_iq = len(X_test_scaled_iq)

# # 初始化預測結果
# y_pred_sj = []
# y_pred_iq = []

# # 取最後一個時間窗口作為初始輸入
# X_input_sj = X_test_scaled_sj[:time_steps].reshape(1, time_steps, -1)
# X_input_iq = X_test_scaled_iq[:time_steps].reshape(1, time_steps, -1)

pred_sj = model_sj.predict(X_test_scaled_sj)
pred_iq = model_iq.predict(X_input_iq)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[98], line 14
#      11 X_input_iq = X_test_scaled_iq[:time_steps].reshape(1, time_steps, -1)
#      13 pred_sj = model_sj.predict(X_input_sj)
# ---> 14 pred_iq = model_iq.predict(X_input_iq)
#
# File D:\anaconda\envs\data\lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File D:\anaconda\envs\data\lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node convolution defined at (most recent call last):
# <stack traces unavailable>
# Depth of output must be a multiple of the number of groups: 64 vs 22
#
# Stack trace for op definition:
# File "D:\anaconda\envs\data\lib\runpy.py", line 197, in _run_module_as_main
# File "D:\anaconda\envs\data\lib\runpy.py", line 87, in _run_code
# File "D:\anaconda\envs\data\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
# File "D:\anaconda\envs\data\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
# File "D:\anaconda\envs\data\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
# File "D:\anaconda\envs\data\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
# File "D:\anaconda\envs\data\lib\asyncio\base_events.py", line 601, in run_forever
# File "D:\anaconda\envs\data\lib\asyncio\base_events.py", line 1905, in _run_once
# File "D:\anaconda\envs\data\lib\asyncio\events.py", line 80, in _run
# File "D:\anaconda\envs\data\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
# File "D:\anaconda\envs\data\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
# File "D:\anaconda\envs\data\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
# File "D:\anaconda\envs\data\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
# File "D:\anaconda\envs\data\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
# File "D:\anaconda\envs\data\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
# File "D:\anaconda\envs\data\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
# File "D:\anaconda\envs\data\lib\site-packages\IPython\core\interactiveshell.py", line 3048, in run_cell
# File "D:\anaconda\envs\data\lib\site-packages\IPython\core\interactiveshell.py", line 3103, in _run_cell
# File "D:\anaconda\envs\data\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
# File "D:\anaconda\envs\data\lib\site-packages\IPython\core\interactiveshell.py", line 3308, in run_cell_async
# File "D:\anaconda\envs\data\lib\site-packages\IPython\core\interactiveshell.py", line 3490, in run_ast_nodes
# File "D:\anaconda\envs\data\lib\site-packages\IPython\core\interactiveshell.py", line 3550, in run_code
# File "C:\Users\User\AppData\Local\Temp\ipykernel_31496\1141668379.py", line 14, in <module>
# File "D:\anaconda\envs\data\lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
# File "D:\anaconda\envs\data\lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 562, in predict
# File "D:\anaconda\envs\data\lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 259, in one_step_on_data_distributed
# File "D:\anaconda\envs\data\lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 249, in one_step_on_data
# File "D:\anaconda\envs\data\lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 104, in predict_step
# File "D:\anaconda\envs\data\lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
# File "D:\anaconda\envs\data\lib\site-packages\keras\src\layers\layer.py", line 908, in __call__
# File "D:\anaconda\envs\data\lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
# File "D:\anaconda\envs\data\lib\site-packages\keras\src\ops\operation.py", line 46, in __call__
# File "D:\anaconda\envs\data\lib\site-packages\keras\src\utils\traceback_utils.py", line 156, in error_handler
# File "D:\anaconda\envs\data\lib\site-packages\keras\src\models\sequential.py", line 213, in call
# File "D:\anaconda\envs\data\lib\site-packages\keras\src\models\functional.py", line 182, in call
# File "D:\anaconda\envs\data\lib\site-packages\keras\src\ops\function.py", line 171, in _run_through_graph
# File "D:\anaconda\envs\data\lib\site-packages\keras\src\models\functional.py", line 637, in call
# File "D:\anaconda\envs\data\lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
# File "D:\anaconda\envs\data\lib\site-packages\keras\src\layers\layer.py", line 908, in __call__
# File "D:\anaconda\envs\data\lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
# File "D:\anaconda\envs\data\lib\site-packages\keras\src\ops\operation.py", line 46, in __call__
# File "D:\anaconda\envs\data\lib\site-packages\keras\src\utils\traceback_utils.py", line 156, in error_handler
# File "D:\anaconda\envs\data\lib\site-packages\keras\src\layers\convolutional\conv1d.py", line 151, in call
# File "D:\anaconda\envs\data\lib\site-packages\keras\src\ops\nn.py", line 1305, in conv
# File "D:\anaconda\envs\data\lib\site-packages\keras\src\backend\tensorflow\nn.py", line 329, in conv
# File "D:\anaconda\envs\data\lib\site-packages\keras\src\backend\tensorflow\nn.py", line 317, in _conv_xla
# File "D:\anaconda\envs\data\lib\site-packages\keras\src\backend\tensorflow\nn.py", line 304, in _conv
#
# 	 [[{{node convolution}}]]
# 	tf2xla conversion failed while converting __inference__conv_xla_164550[]. Run with TF_DUMP_GRAPH_PREFIX=/path/to/dump/dir and --vmodule=xla_compiler=2 to obtain a dump of the compiled functions.
# 	 [[sequential_8_1/conv1d_8_1/StatefulPartitionedCall]] [Op:__inference_one_step_on_data_distributed_164875]

# %%
# 預測 San Juan
for i in range(num_test_sj):
    pred = model_sj.predict(X_input_sj, verbose=0)[0, 0]  # 取得預測值
    y_pred_sj.append(pred)

    # 更新窗口（去掉最舊的數據，加入新的預測值）
    X_input_sj = np.roll(X_input_sj, shift=-1, axis=1)
    X_input_sj[0, -1, -1] = pred  # 插入新的預測值

# 預測 Iquitos
for i in range(num_test_iq):
    pred = model_iq.predict(X_input_iq, verbose=0)[0, 0]  # 取得預測值
    y_pred_iq.append(pred)

    # 更新窗口（去掉最舊的數據，加入新的預測值）
    X_input_iq = np.roll(X_input_iq, shift=-1, axis=1)
    X_input_iq[0, -1, -1] = pred  # 插入新的預測值

# %%
# 將 y_pred_sj 和 y_pred_iq 轉換為整數
y_pred_sj = np.round(y_pred_sj).astype(int)
y_pred_iq = np.round(y_pred_iq).astype(int)
#寫入
benchmark_df = pd.read_csv("data/benchmark.csv")
num_sj = (benchmark_df['city'] == 'sj').sum()
num_iq = (benchmark_df['city'] == 'iq').sum()
benchmark_df.loc[benchmark_df['city'] == 'sj', 'total_cases'] = y_pred_sj[:num_sj]
benchmark_df.loc[benchmark_df['city'] == 'iq', 'total_cases'] = y_pred_iq[:num_iq]
output_path = "data/final_predictions.csv"
benchmark_df.to_csv(output_path, index=False)

# %%
#預測圖
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(y_pred_sj, label="Predicted SJ Cases", color='red', linestyle='dashed')
plt.plot(y_pred_iq, label="Predicted IQ Cases", color='blue', linestyle='dashed')
plt.xlabel("Time")
plt.ylabel("Total Cases")
plt.title("CNN + LSTM Sliding Window Prediction")
plt.legend()
plt.show()
